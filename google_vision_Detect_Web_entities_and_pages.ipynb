# %% [markdown]
# https://cloud.google.com/vision/docs/detecting-web

# %%
def detect_web(path):
    """Detects web annotations given an image."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.web_detection(image=image)
    annotations = response.web_detection

    if annotations.best_guess_labels:
        for label in annotations.best_guess_labels:
            print('\nBest guess label: {}'.format(label.label))

    if annotations.pages_with_matching_images:
        print('\n{} Pages with matching images found:'.format(
            len(annotations.pages_with_matching_images)))

        for page in annotations.pages_with_matching_images:
            print('\n\tPage url   : {}'.format(page.url))

            if page.full_matching_images:
                print('\t{} Full Matches found: '.format(
                       len(page.full_matching_images)))

                for image in page.full_matching_images:
                    print('\t\tImage url  : {}'.format(image.url))

            if page.partial_matching_images:
                print('\t{} Partial Matches found: '.format(
                       len(page.partial_matching_images)))

                for image in page.partial_matching_images:
                    print('\t\tImage url  : {}'.format(image.url))

    if annotations.web_entities:
        print('\n{} Web entities found: '.format(
            len(annotations.web_entities)))

        for entity in annotations.web_entities:
            print('\n\tScore      : {}'.format(entity.score))
            print(u'\tDescription: {}'.format(entity.description))

    if annotations.visually_similar_images:
        print('\n{} visually similar images found:\n'.format(
            len(annotations.visually_similar_images)))

        for image in annotations.visually_similar_images:
            print('\tImage url    : {}'.format(image.url))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(
                response.error.message))

# %%
def detect_web_uri(uri):
    """Detects web annotations in the file located in Google Cloud Storage."""
    from google.cloud import vision
    client = vision.ImageAnnotatorClient()
    image = vision.types.Image()
    image.source.image_uri = uri

    response = client.web_detection(image=image)
    annotations = response.web_detection

    if annotations.best_guess_labels:
        for label in annotations.best_guess_labels:
            print('\nBest guess label: {}'.format(label.label))

    if annotations.pages_with_matching_images:
        print('\n{} Pages with matching images found:'.format(
            len(annotations.pages_with_matching_images)))

        for page in annotations.pages_with_matching_images:
            print('\n\tPage url   : {}'.format(page.url))

            if page.full_matching_images:
                print('\t{} Full Matches found: '.format(
                       len(page.full_matching_images)))

                for image in page.full_matching_images:
                    print('\t\tImage url  : {}'.format(image.url))

            if page.partial_matching_images:
                print('\t{} Partial Matches found: '.format(
                       len(page.partial_matching_images)))

                for image in page.partial_matching_images:
                    print('\t\tImage url  : {}'.format(image.url))

    if annotations.web_entities:
        print('\n{} Web entities found: '.format(
            len(annotations.web_entities)))

        for entity in annotations.web_entities:
            print('\n\tScore      : {}'.format(entity.score))
            print(u'\tDescription: {}'.format(entity.description))

    if annotations.visually_similar_images:
        print('\n{} visually similar images found:\n'.format(
            len(annotations.visually_similar_images)))

        for image in annotations.visually_similar_images:
            print('\tImage url    : {}'.format(image.url))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(
                response.error.message))

# %%
def web_entities_include_geo_results(path):
    """Detects web annotations given an image, using the geotag metadata
    in the image to detect web entities."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    web_detection_params = vision.types.WebDetectionParams(
        include_geo_results=True)
    image_context = vision.types.ImageContext(
        web_detection_params=web_detection_params)

    response = client.web_detection(image=image, image_context=image_context)

    for entity in response.web_detection.web_entities:
        print('\n\tScore      : {}'.format(entity.score))
        print(u'\tDescription: {}'.format(entity.description))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(
                response.error.message))

# %%
def web_entities_include_geo_results_uri(uri):
    """Detects web annotations given an image in the file located in
    Google Cloud Storage., using the geotag metadata in the image to
    detect web entities."""
    from google.cloud import vision
    client = vision.ImageAnnotatorClient()

    image = vision.types.Image()
    image.source.image_uri = uri

    web_detection_params = vision.types.WebDetectionParams(
        include_geo_results=True)
    image_context = vision.types.ImageContext(
        web_detection_params=web_detection_params)

    response = client.web_detection(image=image, image_context=image_context)

    for entity in response.web_detection.web_entities:
        print('\n\tScore      : {}'.format(entity.score))
        print(u'\tDescription: {}'.format(entity.description))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(
                response.error.message))

# %%
detect_web_uri('gs://cloud-samples-data/vision/web/carnaval.jpeg')
# Out:
# Best guess label: karneval germany
#
# 10 Pages with matching images found:
#
# 	Page url   : https://www.expatica.com/de/lifestyle/holidays/karneval-germany-585097/
# 	2 Partial Matches found:
# 		Image url  : https://www.expatica.com/app/uploads/sites/6/2016/02/ladies-1200x675.jpg
# 		Image url  : https://www.expatica.com/app/uploads/sites/6/2016/02/ladies.jpg
#
# 	Page url   : https://www.pinterest.com/carnavalbz/germany/
# 	1 Partial Matches found:
# 		Image url  : https://i.pinimg.com/236x/8a/af/05/8aaf054e76c87a59d1f00e8773619dae.jpg
#
# 	Page url   : https://www.expatica.com/de/lifestyle/holidays/
# 	1 Partial Matches found:
# 		Image url  : https://www.expatica.com/app/uploads/sites/6/2016/02/ladies-370x200.jpg
#
# 	Page url   : https://travelnoire.com/carnival-season-celebrate-2020
# 	1 Partial Matches found:
# 		Image url  : https://legacy.travelnoire.com/wp-content/uploads/2020/03/quinten-de-graaf-KB0Ipylp7dc-unsplash-970x647.jpg
#
# 	Page url   : https://www.sbs.com.au/language/english/mardi-gras-eight-of-the-world-s-biggest-carnival-parties
# 	2 Partial Matches found:
# 		Image url  : https://sl.sbs.com.au/public/image/file/90f99ebe-12a1-4c16-9c71-6d7af25eecdb/crop/16x9_large
# 		Image url  : https://sl.sbs.com.au/public/image/file/90f99ebe-12a1-4c16-9c71-6d7af25eecdb/crop/16x9
#
# 	Page url   : https://www.esn.org/blog/12-places-visit-during-carnival
# 	1 Full Matches found:
# 		Image url  : https://www.esn.org/blog/sites/default/files/3_22.jpg
#
# 	Page url   : https://blog.esl-languages.com/blog/travel/worlds-best-carnivals/
# 	1 Partial Matches found:
# 		Image url  : https://i0.wp.com/blog.esl-languages.com/wp-content/uploads/2018/02/Rio.jpg?resize=720%2C480&ssl=1
#
# 	Page url   : https://www.lacerveceriadebarrio.com/us/news/mexican-restaurant-near-miami-broward-carnival/
# 	1 Full Matches found:
# 		Image url  : https://www.lacerveceriadebarrio.com/us/wp-content/uploads/2019/09/people-dance-carnival-festival-sports-samba-1407044-pxhere.com_.jpg
#
# 	Page url   : https://news.airbnb.com/celebrate-carnival-in-these-lesser-known-destinations/
# 	1 Full Matches found:
# 		Image url  : https://news.airbnb.com/wp-content/uploads/sites/4/2019/02/Press-Room-Post-carnival-3.jpg
#
# 	Page url   : https://www.stlucia.org/en/events/saint-lucia-carnival/
# 	1 Full Matches found:
# 		Image url  : https://www.stlucia.org/wp-content/uploads/2019/05/278848-unsplash-opti.jpg
#
# 10 Web entities found:
#
# 	Score      : 0.9104999899864197
# 	Description: Carnival in Rio de Janeiro
#
# 	Score      : 0.7170000076293945
# 	Description: Carnival
#
# 	Score      : 0.6825000047683716
# 	Description: Rio de Janeiro
#
# 	Score      : 0.6799499988555908
# 	Description: Venice Carnival
#
# 	Score      : 0.6304500102996826
# 	Description: Germany
#
# 	Score      : 0.6097000241279602
# 	Description:
#
# 	Score      : 0.531749963760376
# 	Description: Jamaica Carnival
#
# 	Score      : 0.4986000061035156
# 	Description: Festival
#
# 	Score      : 0.4768500030040741
# 	Description: Notting Hill Carnival
#
# 	Score      : 0.45855000615119934
# 	Description: Caribbean
#
# 9 visually similar images found:
#
# 	Image url    : https://www.expatica.com/app/uploads/sites/6/2016/02/ladies-150x150.jpg
# 	Image url    : https://editorial01.shutterstock.com/wm-preview-1500/9602481a/962b9366/deu-karneval-der-kulturen-berlin-germany-shutterstock-editorial-9602481a.jpg
# 	Image url    : https://l450v.alamy.com/450v/g24htf/portrait-of-dancing-woman-in-costume-on-carnival-of-cultures-karneval-g24htf.jpg
# 	Image url    : https://assets0.dostuffmedia.com/uploads/aws_asset/aws_asset/4408481/f5223add-5a15-4483-968d-67fb4fe5b9a0.jpg
# 	Image url    : https://c8.alamy.com/comp/BBWBPR/germany-berlin-carnival-of-cultures-brazilian-woman-in-costume-BBWBPR.jpg
# 	Image url    : https://previews.123rf.com/images/hanohiki/hanohiki1706/hanohiki170600057/79690391-people-at-carnival-of-cultures-carnival-of-cultures-in-berlin-germany-.jpg
# 	Image url    : https://thumbs.dreamstime.com/b/people-karneval-der-kulturen-carnival-cultures-berl-berlin-germany-june-berlin-germany-93768049.jpg
# 	Image url    : https://estaticos.efe.com/efecom/recursos2/imagen.aspx?lVW2oAh2vjMlGgl8ih2v-P-2fR5VXFJPCCxsQ4TncnkXVSTX-P-2bAoG0sxzXPZPAk5l-P-2fU5UB9FyZoYGIBL-P-2bcA7doxjU0g-P-3d-P-3d
# 	Image url    : https://www.imago-images.de/bild/st/0083286664/w.jpg

# %%
web_entities_include_geo_results_uri('gs://cloud-samples-data/vision/web/carnaval.jpeg')
# Out:
# 	Score      : 0.8938499689102173
# 	Description: Carnival in Rio de Janeiro
#
# 	Score      : 0.7245000004768372
# 	Description: Germany
#
# 	Score      : 0.7184000015258789
# 	Description: Carnival
#
# 	Score      : 0.7157999873161316
# 	Description: Venice Carnival
#
# 	Score      : 0.6616500020027161
# 	Description: Rio de Janeiro
#
# 	Score      : 0.6261000037193298
# 	Description:
#
# 	Score      : 0.5257499814033508
# 	Description: Jamaica Carnival
#
# 	Score      : 0.5016999840736389
# 	Description: Festival
#
# 	Score      : 0.4849500060081482
# 	Description: Notting Hill Carnival
#
# 	Score      : 0.4535999894142151
# 	Description: Caribbean
